# %%
import matplotlib.pyplot as plt
import math
import numpy as np

eventu = [0.169, 0.256, 0.178, 0.191, 0.197, 0.22, 0.187, 0.185, 0.178, 0.208, 0.193, 0.197, 0.195, 0.248, 0.28, 0.415, 0.765, 1.556, 2.941, 6.222, 13.053, 28.814, 64.214, 160.935, 482.814]

always = [0.183, 0.159, 0.143, 0.185, 0.188, 0.216, 0.133, 0.15, 0.157, 0.145, 0.187, 0.143, 0.181, 0.18, 0.291, 0.378, 0.778, 1.747, 3.059, 5.942, 14.009, 33.342, 69.666, 147.163, 770.774]

conj_always_eventu = [0.186, 0.137, 0.14, 0.126, 0.13, 0.144, 0.129, 0.142, 0.133, 0.145, 0.172, 0.155, 0.21, 0.231, 0.323, 0.645, 1.481, 2.83, 5.786, 14.147, 31.017, 67.975, 150.979, 807.843]

conj_eventu_always = [0.128, 0.124, 0.137, 0.121, 0.139, 0.129, 0.128, 0.136, 0.128, 0.154, 0.124, 0.143, 0.126, 0.145, 0.126, 0.14, 0.127, 0.142, 0.131, 0.128, 0.152, 0.13, 0.143, 0.132]

release = [0.127, 0.123, 0.126, 0.132, 0.129, 0.136, 0.134, 0.139, 0.142, 0.129, 0.137, 0.134, 0.141, 0.13, 0.126, 0.147, 0.131, 0.161, 0.135, 0.148, 0.131, 0.14, 0.147, 0.133]

# plt.plot(np.log10(eventu))
# plt.plot(np.log10(always))
plt.plot(eventu)
plt.plot(always)
plt.plot(conj_always_eventu)
# plt.plot(conj_eventu_always)
# plt.plot(release)
# plt.loglog()
plt.legend(['E(n)', 'S(n)', 'C(n)']) #, 'Q(n)', 'R(n)'])
plt.title('Runtimes for pattern formulas (rLTL)')

plt.yscale('log')

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

rltl_nofair = [1.546, 1.247, 7.967, 17.252, 33.915, 104.199, 336.785, 1241.023, 3311.418, 10790.695]

rltl_fair = [1.479, 3.881, 25.694, 88.793, 281.29, 980.906, 2451.749, 6771.852, 31489.44]

ltl_nofair = []

ltl_fair = [0.526, 2.923, 16.876, 63.697, 241.61, 707.837, 1392.563, 5409.193, 28369.41]

xi = list(range(1, 10))
plt.plot(xi, rltl_fair)
plt.plot(xi, ltl_fair)
plt.legend(['rLTL', 'LTL'])
# plt.title('Model-checking runtimes')
plt.yscale('log')
plt.xlabel('n')
plt.ylabel('Runtime (sec.)')
# plt.xticks([1,9])

plt.savefig("scalability.png")
